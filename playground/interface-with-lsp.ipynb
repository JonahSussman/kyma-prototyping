# %%
import asyncio
import logging
import pathlib
import os
import threading
import json
from pathlib import PurePath

from typing import AsyncIterator, Any, Iterator, List, Dict, Union, Tuple
from typing_extensions import NotRequired, TypedDict
from contextlib import asynccontextmanager

from monitors4codegen.multilspy import multilspy_types
from monitors4codegen.multilspy import LanguageServer, SyncLanguageServer
from monitors4codegen.multilspy.multilspy_config import MultilspyConfig
from monitors4codegen.multilspy.multilspy_logger import MultilspyLogger
from monitors4codegen.multilspy.multilspy_exceptions import MultilspyException
from monitors4codegen.multilspy.lsp_protocol_handler import lsp_types
from monitors4codegen.multilspy.lsp_protocol_handler.lsp_requests import LspRequest
from monitors4codegen.multilspy.lsp_protocol_handler.lsp_constants import LSPConstants
from monitors4codegen.multilspy.language_servers.eclipse_jdtls.eclipse_jdtls import EclipseJDTLS

# %%
# Monkey patch some requests
# 
# Technically, there should be equivalent SyncLanguageServer implementations for
# each one of the LanguageServer methods, but that was a lot of extra code, and
# I'm not using SyncLanguageServer anyway. Additionally, there should be a
# corresponding method defined on LspRequest, but again... too lazy. It should
# look like this if I were doing it properly:

"""
def SyncLanguageServer_request_workspace_symbol(self, query: str) -> List[multilspy_types.UnifiedSymbolInformation]:
  result = asyncio.run_coroutine_threadsafe(
    self.language_server.request_workspace_symbol(query), self.loop
  ).result()
  return result

async def LspRequest_workspace_symbol(
  self, params: lsp_types.WorkspaceSymbolParams
) -> Union[List["lsp_types.SymbolInformation"], List["lsp_types.WorkspaceSymbol"], None]:
  return await self.send_request("workspace/symbol", params)

SyncLanguageServer.request_workspace_symbol = SyncLanguageServer_request_workspace_symbol
LspRequest.workspace_symbol = LspRequest_workspace_symbol
"""

# SyncLanguageServer wraps a LanguageServer. EclipseJDTLS is a LanguageServer.
# LanguageServer has a LanguageServerHandler attribute called 'server'.
# Confusing, I know.


async def LanguageServer_request_workspace_symbol(self: LanguageServer, query: str)  -> List[multilspy_types.UnifiedSymbolInformation]:
  if not self.server_started:
    self.logger.log(
      "request_workspace_symbols called before Language Server started",
      logging.ERROR,
    )
    raise MultilspyException("Language Server not started")
  
  response: Union[List["lsp_types.SymbolInformation"], List["lsp_types.WorkspaceSymbol"], None] = await self.server.send.send_request(
    "workspace/symbol",
    {
      "query": query,
    }
  )

  ret: List[multilspy_types.UnifiedSymbolInformation] = []

  assert isinstance(response, list)
  for item in response:
    assert isinstance(item, dict)
    assert LSPConstants.NAME in item
    assert LSPConstants.KIND in item

    ret.append(multilspy_types.UnifiedSymbolInformation(**item))

  return ret

LanguageServer.request_workspace_symbol = LanguageServer_request_workspace_symbol


async def LanguageServer_request_document_diagnostic(self: LanguageServer, relative_file_path: str) -> List[multilspy_types.UnifiedSymbolInformation]:
  if not self.server_started:
    self.logger.log(
      "request_document_diagnostic called before Language Server started",
      logging.ERROR,
    )
    raise MultilspyException("Language Server not started")
  
  with self.open_file(relative_file_path):
    response: lsp_types.DocumentDiagnosticReport = await self.server.send.send_request(
    "textDocument/diagnostic",
    {
      LSPConstants.TEXT_DOCUMENT: {
        LSPConstants.URI: pathlib.Path(
          str(PurePath(self.repository_root_path, relative_file_path))
        ).as_uri()
      }
    })

  return response

LanguageServer.request_document_diagnostic = LanguageServer_request_document_diagnostic


async def LanguageServer_execute_command(self: LanguageServer, command: str, arguments: List["Any"]):
  if not self.server_started:
    self.logger.log(
      "execute_command called before Language Server started",
      logging.ERROR,
    )
    raise MultilspyException("Language Server not started")

  return await self.server.send.send_request(
    "workspace/executeCommand",
    {
      "command": command,
      "arguments": arguments,
    }
  )

LanguageServer.execute_command = LanguageServer_execute_command

async def EclipseJDTLS_execute_command(self: EclipseJDTLS, command: str, arguments: List["Any"]):
  print("poop")
  return await super(EclipseJDTLS, self).execute_command(command, [json.dumps(x) for x in arguments])

EclipseJDTLS.execute_command = EclipseJDTLS_execute_command


LanguageServer.diagnostics = {}
LanguageServer.diagnostics_conditions = {}
LanguageServer.diagnostics_conditions_lock = threading.Lock()

def LanguageServer_get_diagnostic(self: LanguageServer, uri: str, timeout: float = 30.0):
  # with self.diagnostics_conditions_lock:
  #   if uri not in self.diagnostics_conditions:
  #     self.diagnostics_conditions[uri] = threading.Condition()

  # cond: threading.Condition = self.diagnostics_conditions[uri]
  # with cond:
  #   did_timeout = False

  #   while not did_timeout and uri not in self.diagnostics:
  #     did_timeout = cond.wait(timeout)

  if uri in self.diagnostics:
    return (True, self.diagnostics[uri])
  else:
    return (False, None)

LanguageServer.get_diagnostic = LanguageServer_get_diagnostic


def start_server_decorator(start_server_method):
  @asynccontextmanager
  async def decorate_start_server(self: EclipseJDTLS):
    async with start_server_method(self):
      async def print_it(params):
        print(params)
        return
      
      async def handle_publish_diagnostic(params):
        # TODO: Support that whole "wait till the build is done" thing so we can
        # do incremental builds

        print('handle_publish_diagnostic')
        uri = params['uri']
        diagnostics = params['diagnostics']
        print(f"uri: {uri}\ndiagnostics: {diagnostics}")

        # with self.diagnostics_conditions_lock:
        #   if uri not in self.diagnostics_conditions:
        #     self.diagnostics_conditions[uri] = threading.Condition()

        # cond: threading.Condition = self.diagnostics_conditions[uri]
        # with cond:
        self.diagnostics[uri] = diagnostics
          # cond.notify_all()

      self.server.on_notification("textDocument/publishDiagnostics", handle_publish_diagnostic)
      self.server.on_notification("language/actionableNotification", print_it)
      self.server.on_notification("language/status", print_it)

      yield self

  return decorate_start_server

EclipseJDTLS.start_server = start_server_decorator(EclipseJDTLS.start_server)


# def EclipseJDTLS_get_diagnostic(self, uri):

# %%
config = MultilspyConfig.from_dict({"code_language": "java"})
logger = MultilspyLogger()
lsp = LanguageServer.create(config, logger, "/home/jonah/Projects/kyma-prototyping/examples/complex-numbers")

# %%
# Without the 'with' block
# server_gen = lsp.start_server()
# await server_gen.__aenter__()
# ...
# await server_gen.__aexit__(None, None, None)

# With the 'with' block:
# async with lsp.start_server():
#   ...

server_gen = lsp.start_server()
await server_gen.__aenter__()

print(await lsp.request_definition(
  "src/main/java/net/jsussman/dummyapp/App.java",
  7-1,
  34-1,
))

print(await lsp.request_hover(
  "src/main/java/net/jsussman/dummyapp/App.java",
  7-1,
  34-1,
))

print(await lsp.request_document_symbols(
  "src/main/java/net/jsussman/dummyapp/App.java",
))

print(await lsp.request_document_symbols(
  "src/main/java/net/jsussman/complexnumber/ComplexNumber.java",
))

# print(await lsp.request_all)

print(f"""References to Bicycle: {await lsp.request_references(
  "src/main/java/net/jsussman/complexnumber/ComplexNumber.java",
  2,
  39,
)}""")

diagnostic_str = f"file://{os.path.join(lsp.repository_root_path, 'src/main/java/net/jsussman/complexnumber/ComplexNumber.java')}"
print(f"""This is it! {lsp.get_diagnostic(diagnostic_str)}""")


print(await lsp.execute_command(
  "java.navigate.openTypeHierarchy",
  [
    # lsp_types.TextDocumentPositionParams(
    #   textDocument=lsp_types.TextDocumentIdentifier(
    #     uri="file:///home/jonah/Projects/kyma-prototyping/examples/complex-numbers/src/main/java/net/jsussman/inheritance/MountainBike.java",
    #   ),
    #   position=lsp_types.Position(
    #     line=2,
    #     character=12,
    #   ),
    # ),

    {
      "textDocument": {
        "uri": "file:///home/jonah/Projects/kyma-prototyping/examples/complex-numbers/src/main/java/net/jsussman/inheritance/MountainBike.java",
      },
      "position": {
        "line": 2,
        "character": 12,
      }
    },

    # # textdocumentpositionparams
    # {
    #   # "direction": "2",
    #   # "resolve": "1",
    #   "textDocument": {
    #     "uri": "file:///home/jonah/Projects/kyma-prototyping/examples/complex-numbers/src/main/java/net/jsussman/inheritance/MountainBike.java",
    #   }, 
    #   "position": {
    #     "line": "2",
    #     "character": "12",
    #   },
    # },
    # direction
    2,
    # resolve
    1,
  ],
))

await server_gen.__aexit__(None, None, None)

# try:
# print(lsp.request_document_diagnostic(
#   "src/main/java/net/jsussman/complexnumber/ComplexNumber.java"
# ))

# lsp.language_server.server.notify.send_notification(
#   "textDocument/didSave",
#   {
#     "textDocument": "src/main/java/net/jsussman/complexnumber/ComplexNumber.java",
#   }
# )

# print(f"""this is it! {lsp.get_diagnostic(
#   'file:///home/jonah/Projects/kyma-prototyping/examples/complex-numbers/src/main/java/net/jsussman/complexnumber/ComplexNumber.java',
# )}""")

# import time
# time.sleep(10)

# except Exception as e: 
  # print(e)
# Out:
# handle_publish_diagnostic
# uri: file:///home/jonah/Projects/kyma-prototyping/examples/complex-numbers
# diagnostics: []
# handle_publish_diagnostic
# uri: file:///home/jonah/Projects/kyma-prototyping/examples/complex-numbers/pom.xml
# diagnostics: []
# handle_publish_diagnostic
# uri: file:///home/jonah/Projects/kyma-prototyping/examples/complex-numbers
# diagnostics: []
# handle_publish_diagnostic
# uri: file:///home/jonah/Projects/kyma-prototyping/examples/complex-numbers/pom.xml
# diagnostics: []
# handle_publish_diagnostic
# uri: file:///home/jonah/Projects/kyma-prototyping/examples/complex-numbers
# diagnostics: [{'range': {'start': {'line': 0, 'character': 0}, 'end': {'line': 0, 'character': 0}}, 'severity': 2, 'code': '0', 'source': 'Java', 'message': 'Build path specifies execution environment JavaSE-1.7. There are no JREs installed in the workspace that are strictly compatible with this environment. '}, {'range': {'start': {'line': 0, 'character': 0}, 'end': {'line': 0, 'character': 0}}, 'severity': 2, 'code': '0', 'source': 'Java', 'message': 'The compiler compliance specified is 1.7 but a JRE 17 is used'}]
# handle_publish_diagnostic
# uri: file:///home/jonah/Projects/kyma-prototyping/examples/complex-numbers/pom.xml
# diagnostics: []
# handle_publish_diagnostic
# uri: file:///home/jonah/Projects/kyma-prototyping/examples/complex-numbers/src/main/java/net/jsussman/complexnumber/ComplexNumber.java
# diagnostics: [{'range': {'start': {'line': 25, 'character': 12}, 'end': {'line': 25, 'character': 13}}, 'severity': 2, 'code': '536870973', 'source': 'Java', 'message': 'The value of the local variable b is not used', 'tags': [1]}]
# handle_publish_diagnostic
# uri: file:///home/jonah/Projects/kyma-prototyping/examples/complex-numbers
# diagnostics: [{'range': {'start': {'line': 0, 'character': 0}, 'end': {'line': 0, 'character': 0}}, 'severity': 2, 'code': '0', 'source': 'Java', 'message': 'Build path specifies execution environment JavaSE-1.7. There are no JREs installed in the workspace that are strictly compatible with this environment. '}, {'range': {'start': {'line': 0, 'character': 0}, 'end': {'line': 0, 'character': 0}}, 'severity': 2, 'code': '0', 'source': 'Java', 'message': 'The compiler compliance specified is 1.7 but a JRE 17 is used'}]
# handle_publish_diagnostic
# uri: file:///home/jonah/Projects/kyma-prototyping/examples/complex-numbers/pom.xml
# diagnostics: []
# handle_publish_diagnostic
# uri: file:///home/jonah/Projects/kyma-prototyping/examples/complex-numbers/src/main/java/net/jsussman/complexnumber/ComplexNumber.java
# diagnostics: [{'range': {'start': {'line': 25, 'character': 12}, 'end': {'line': 25, 'character': 13}}, 'severity': 2, 'code': '536870973', 'source': 'Java', 'message': 'The value of the local variable b is not used', 'tags': [1]}]
# []
# {'contents': ''}
# ([{'name': 'net.jsussman.dummyapp', 'kind': 4, 'range': {'start': {'line': 0, 'character': 0}, 'end': {'line': 0, 'character': 30}}, 'selectionRange': {'start': {'line': 0, 'character': 0}, 'end': {'line': 0, 'character': 30}}, 'detail': ''}, {'name': 'App', 'kind': 5, 'range': {'start': {'line': 4, 'character': 0}, 'end': {'line': 11, 'character': 1}}, 'selectionRange': {'start': {'line': 6, 'character': 13}, 'end': {'line': 6, 'character': 16}}, 'detail': ''}, {'name': 'main(String[])', 'kind': 6, 'range': {'start': {'line': 7, 'character': 2}, 'end': {'line': 10, 'character': 3}}, 'selectionRange': {'start': {'line': 7, 'character': 21}, 'end': {'line': 7, 'character': 25}}, 'detail': ' : void'}], None)
# ([{'name': 'net.jsussman.complexnumber', 'kind': 4, 'range': {'start': {'line': 0, 'character': 0}, 'end': {'line': 0, 'character': 35}}, 'selectionRange': {'start': {'line': 0, 'character': 0}, 'end': {'line': 0, 'character': 35}}, 'detail': ''}, {'name': 'ComplexNumber', 'kind': 5, 'range': {'start': {'line': 4, 'character': 0}, 'end': {'line': 60, 'character': 1}}, 'selectionRange': {'start': {'line': 7, 'character': 13}, 'end': {'line': 7, 'character': 26}}, 'detail': ''}, {'name': 'real', 'kind': 8, 'range': {'start': {'line': 8, 'character': 2}, 'end': {'line': 9, 'character': 22}}, 'selectionRange': {'start': {'line': 9, 'character': 17}, 'end': {'line': 9, 'character': 21}}, 'detail': ''}, {'name': 'imag', 'kind': 8, 'range': {'start': {'line': 10, 'character': 2}, 'end': {'line': 10, 'character': 22}}, 'selectionRange': {'start': {'line': 10, 'character': 17}, 'end': {'line': 10, 'character': 21}}, 'detail': ''}, {'name': 'ComplexNumber(double, double)', 'kind': 9, 'range': {'start': {'line': 12, 'character': 2}, 'end': {'line': 16, 'character': 3}}, 'selectionRange': {'start': {'line': 13, 'character': 9}, 'end': {'line': 13, 'character': 22}}, 'detail': ''}, {'name': 'getReal()', 'kind': 6, 'range': {'start': {'line': 18, 'character': 2}, 'end': {'line': 22, 'character': 3}}, 'selectionRange': {'start': {'line': 19, 'character': 16}, 'end': {'line': 19, 'character': 23}}, 'detail': ' : double'}, {'name': 'getImag()', 'kind': 6, 'range': {'start': {'line': 24, 'character': 2}, 'end': {'line': 28, 'character': 3}}, 'selectionRange': {'start': {'line': 24, 'character': 16}, 'end': {'line': 24, 'character': 23}}, 'detail': ' : double'}, {'name': 'add(ComplexNumber, ComplexNumber)', 'kind': 6, 'range': {'start': {'line': 30, 'character': 2}, 'end': {'line': 33, 'character': 3}}, 'selectionRange': {'start': {'line': 31, 'character': 30}, 'end': {'line': 31, 'character': 33}}, 'detail': ' : ComplexNumber'}, {'name': 'sub(ComplexNumber, ComplexNumber)', 'kind': 6, 'range': {'start': {'line': 35, 'character': 2}, 'end': {'line': 38, 'character': 3}}, 'selectionRange': {'start': {'line': 36, 'character': 30}, 'end': {'line': 36, 'character': 33}}, 'detail': ' : ComplexNumber'}, {'name': 'mul(ComplexNumber, ComplexNumber)', 'kind': 6, 'range': {'start': {'line': 40, 'character': 2}, 'end': {'line': 45, 'character': 3}}, 'selectionRange': {'start': {'line': 41, 'character': 30}, 'end': {'line': 41, 'character': 33}}, 'detail': ' : ComplexNumber'}, {'name': 'div(ComplexNumber, ComplexNumber)', 'kind': 6, 'range': {'start': {'line': 47, 'character': 2}, 'end': {'line': 53, 'character': 3}}, 'selectionRange': {'start': {'line': 48, 'character': 30}, 'end': {'line': 48, 'character': 33}}, 'detail': ' : ComplexNumber'}, {'name': 'toString()', 'kind': 6, 'range': {'start': {'line': 55, 'character': 2}, 'end': {'line': 59, 'character': 3}}, 'selectionRange': {'start': {'line': 57, 'character': 16}, 'end': {'line': 57, 'character': 24}}, 'detail': ' : String'}], None)
# References to Bicycle: [{'uri': 'file:///home/jonah/Projects/kyma-prototyping/examples/complex-numbers/src/main/java/net/jsussman/complexnumber/ComplexNumber.java', 'range': {'start': {'line': 2, 'character': 7}, 'end': {'line': 2, 'character': 39}}, 'absolutePath': '/home/jonah/Projects/kyma-prototyping/examples/complex-numbers/src/main/java/net/jsussman/complexnumber/ComplexNumber.java', 'relativePath': 'src/main/java/net/jsussman/complexnumber/ComplexNumber.java'}, {'uri': 'file:///home/jonah/Projects/kyma-prototyping/examples/complex-numbers/src/main/java/net/jsussman/complexnumber/ComplexNumber.java', 'range': {'start': {'line': 25, 'character': 4}, 'end': {'line': 25, 'character': 11}}, 'absolutePath': '/home/jonah/Projects/kyma-prototyping/examples/complex-numbers/src/main/java/net/jsussman/complexnumber/ComplexNumber.java', 'relativePath': 'src/main/java/net/jsussman/complexnumber/ComplexNumber.java'}, {'uri': 'file:///home/jonah/Projects/kyma-prototyping/examples/complex-numbers/src/main/java/net/jsussman/complexnumber/ComplexNumber.java', 'range': {'start': {'line': 25, 'character': 20}, 'end': {'line': 25, 'character': 27}}, 'absolutePath': '/home/jonah/Projects/kyma-prototyping/examples/complex-numbers/src/main/java/net/jsussman/complexnumber/ComplexNumber.java', 'relativePath': 'src/main/java/net/jsussman/complexnumber/ComplexNumber.java'}, {'uri': 'file:///home/jonah/Projects/kyma-prototyping/examples/complex-numbers/src/main/java/net/jsussman/inheritance/MountainBike.java', 'range': {'start': {'line': 2, 'character': 27}, 'end': {'line': 2, 'character': 34}}, 'absolutePath': '/home/jonah/Projects/kyma-prototyping/examples/complex-numbers/src/main/java/net/jsussman/inheritance/MountainBike.java', 'relativePath': 'src/main/java/net/jsussman/inheritance/MountainBike.java'}]
# This is it! (True, [{'range': {'start': {'line': 25, 'character': 12}, 'end': {'line': 25, 'character': 13}}, 'severity': 2, 'code': '536870973', 'source': 'Java', 'message': 'The value of the local variable b is not used', 'tags': [1]}])
# poop
# {'name': 'MountainBike', 'detail': 'net.jsussman.inheritance', 'kind': 5, 'deprecated': False, 'uri': 'file:///home/jonah/Projects/kyma-prototyping/examples/complex-numbers/src/main/java/net/jsussman/inheritance/MountainBike.java', 'range': {'start': {'line': 2, 'character': 0}, 'end': {'line': 34, 'character': 1}}, 'selectionRange': {'start': {'line': 2, 'character': 6}, 'end': {'line': 2, 'character': 18}}, 'parents': [{'name': 'Bicycle', 'detail': 'net.jsussman.inheritance', 'kind': 5, 'deprecated': False, 'uri': 'file:///home/jonah/Projects/kyma-prototyping/examples/complex-numbers/src/main/java/net/jsussman/inheritance/Bicycle.java', 'range': {'start': {'line': 2, 'character': 0}, 'end': {'line': 35, 'character': 1}}, 'selectionRange': {'start': {'line': 2, 'character': 13}, 'end': {'line': 2, 'character': 20}}, 'data': {'element': '=complex-numbers/src\\/main\\/java=/optional=/true=/=/maven.pomderived=/true=/<net.jsussman.inheritance{Bicycle.java[Bicycle'}}], 'children': [], 'data': {'element': '=complex-numbers/src\\/main\\/java=/optional=/true=/=/maven.pomderived=/true=/<net.jsussman.inheritance{MountainBike.java[MountainBike'}}
# False
